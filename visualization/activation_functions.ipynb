# %% [markdown]
# # Plots of activation functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

plt.rcParams['text.usetex'] = True
plt.rcParams.update({"font.size": 18})

# %%
plt.figure(figsize=(7, 4))
x = np.linspace(-3, 3, 200)
plt.plot(x, np.maximum(x, 0))
plt.grid()
plt.savefig(f"relu.png", bbox_inches="tight")
plt.savefig(f"relu.pdf", bbox_inches="tight")

# %% [markdown]
# ### Tanh

# %%
plt.figure(figsize=(7, 4))
x = np.linspace(-3, 3, 200)
plt.plot(x, np.tanh(x))
plt.grid()
plt.savefig(f"tanh.png", bbox_inches="tight")
plt.savefig(f"tanh.pdf", bbox_inches="tight")
